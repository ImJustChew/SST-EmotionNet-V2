# %%
import os
import numpy as np
import scipy.io as sio
from sklearn.model_selection import train_test_split
from mne.filter import filter_data
from scipy.interpolate import griddata
import mne

# Define the paths
train_specInput_root_path = './SEED_input_data/train/feature'
train_tempInput_root_path = './SEED_input_data/train/temporal'
train_label_root_path = './SEED_input_data/train/label'

test_specInput_root_path = './SEED_input_data/test/feature'
test_tempInput_root_path = './SEED_input_data/test/temporal'
test_label_root_path = './SEED_input_data/test/label'

# %%
# Create directories if they do not exist
for path in [train_specInput_root_path, train_tempInput_root_path, train_label_root_path,
             test_specInput_root_path, test_tempInput_root_path, test_label_root_path]:
    os.makedirs(path, exist_ok=True)

# Define the input folder path
input_folder_path = '..\SST-EmotionNet\Preprocessed_EEG'

# Frequency bands
bands = {
    'delta': (1, 4),
    'theta': (4, 8),
    'alpha': (8, 13),
    'beta': (14, 30),
    'gamma': (31, 50)
}

# Electrode positions
electrode_positions = {
    'FP1': (0, 3), 'FPZ': (0, 4), 'FP2': (0, 5),
    'AF3': (1, 3), 'AF4': (1, 5),
    'F7': (2, 0), 'F5': (2, 1), 'F3': (2, 2), 'F1': (2, 3), 'FZ': (2, 4), 'F2': (2, 5), 'F4': (2, 6), 'F6': (2, 7), 'F8': (2, 8),
    'FT7': (3, 0), 'FC5': (3, 1), 'FC3': (3, 2), 'FC1': (3, 3), 'FCZ': (3, 4), 'FC2': (3, 5), 'FC4': (3, 6), 'FC6': (3, 7), 'FT8': (3, 8),
    'T7': (4, 0), 'C5': (4, 1), 'C3': (4, 2), 'C1': (4, 3), 'CZ': (4, 4), 'C2': (4, 5), 'C4': (4, 6), 'C6': (4, 7), 'T8': (4, 8),
    'TP7': (5, 0), 'CP5': (5, 1), 'CP3': (5, 2), 'CP1': (5, 3), 'CPZ': (5, 4), 'CP2': (5, 5), 'CP4': (5, 6), 'CP6': (5, 7), 'TP8': (5, 8),
    'P7': (6, 0), 'P5': (6, 1), 'P3': (6, 2), 'P1': (6, 3), 'PZ': (6, 4), 'P2': (6, 5), 'P4': (6, 6), 'P6': (6, 7), 'P8': (6, 8),
    'PO7': (7, 0), 'PO5': (7, 1), 'PO3': (7, 2), 'POZ': (7, 3), 'PO4': (7, 4), 'PO6': (7, 5), 'PO8': (7, 6),
    'CB1': (8, 0), 'O1': (8, 1), 'OZ': (8, 2), 'O2': (8, 3), 'CB2': (8, 4)
}

# Example channel names corresponding to the EEG data indices
channel_names  = ['FP1', 'FPZ', 'FP2', 'AF3', 'AF4', 'F7', 'F5', 'F3', 'F1', 'FZ', 'F2', 'F4', 'F6', 'F8', 'FT7', 'FC5', 'FC3', 'FC1', 'FCZ', 'FC2', 'FC4', 'FC6', 'FT8', 'T7', 'C5', 'C3', 'C1', 'CZ', 'C2', 'C4', 'C6', 'T8', 'TP7', 'CP5', 'CP3', 'CP1', 'CPZ', 'CP2', 'CP4', 'CP6', 'TP8', 'P7', 'P5', 'P3', 'P1', 'PZ', 'P2', 'P4', 'P6', 'P8', 'PO7', 'PO5', 'PO3', 'POZ', 'PO4', 'PO6', 'PO8', 'CB1', 'O1', 'OZ', 'O2', 'CB2']

# %%
subject_files = {}

for file in os.listdir(input_folder_path):
    if file.endswith('.mat') and file != 'label.mat':
        subject_id = int(file.split('_')[0])
        if subject_id not in subject_files:
            subject_files[subject_id] = []
        subject_files[subject_id].append(file)

label_data = sio.loadmat(os.path.join(input_folder_path, 'label.mat'))['label'].flatten()

subjects_data = []

for subject_id, files in subject_files.items():
    files.sort()
    for session_id, file in enumerate(files):
        file_path = os.path.join(input_folder_path, file)
        data = sio.loadmat(file_path)
        eeg_keys = [key for key in data.keys() if 'eeg' in key]
        eeg_data = [data[key] for key in sorted(eeg_keys, key=lambda x: int(x.split('eeg')[-1]))]
        trial_indices = np.arange(15)
        train_indices, test_indices = train_test_split(trial_indices, test_size=0.1, random_state=40) # change form 42 to 40 for test
        print(len(train_indices), len(test_indices))
        subjects_data.append((eeg_data, label_data, subject_id, session_id, train_indices, test_indices))
# Out:
# 13 2
# 13 2
# 13 2
# 13 2
# 13 2
# 13 2
# 13 2
# 13 2
# 13 2
# 13 2
# 13 2
# 13 2
# 13 2
# 13 2
# 13 2
# 13 2
# 13 2
# 13 2
# 13 2
# 13 2
# 13 2
# 13 2
# 13 2
# 13 2
# 13 2
# 13 2
# 13 2
# 13 2
# 13 2
# 13 2
# 13 2
# 13 2
# 13 2
# 13 2
# 13 2
# 13 2
# 13 2
# 13 2
# 13 2
# 13 2
# 13 2
# 13 2
# 13 2
# 13 2
# 13 2

# %%
import time
from sklearn.decomposition import PCA

def downsample_to_25_samples(data):
    n_channels, n_samples = data.shape
    segment_length = n_samples // 25
    downsampled_data = np.zeros((n_channels, 25))
    
    for i in range(25):
        start_idx = i * segment_length
        end_idx = start_idx + segment_length
        downsampled_data[:, i] = np.mean(data[:, start_idx:end_idx], axis=1)
    
    return downsampled_data

def extract_de_features(data, sfreq, bands):
    de_features = []
    for band, (low_freq, high_freq) in bands.items():
        filtered_data = filter_data(data, sfreq, low_freq, high_freq, verbose=False)
        de_feature = np.log(np.var(filtered_data, axis=-1))
        de_features.append(de_feature)
    return np.array(de_features)

def cubic_spline_interpolation(array, target_resolution=(32, 32)):
    """
    Perform cubic spline interpolation to transform a 2D array of shape (9, 9, 1) to a higher resolution (32, 32, 1).
    
    Parameters:
    array (np.ndarray): Input array of shape (9, 9, 1).
    target_resolution (tuple): Target resolution (height, width).
    
    Returns:
    np.ndarray: Interpolated array of shape (target_resolution[0], target_resolution[1], 1).
    """
    h, w = target_resolution
    input_h, input_w = array.shape[:2]
    
    # Create the coordinate grid for the input array
    grid_x, grid_y = np.mgrid[0:input_h, 0:input_w]
    
    # Flatten the grid and the input array
    points = np.vstack((grid_x.ravel(), grid_y.ravel())).T
    values = array.ravel()
    
    # Create the coordinate grid for the target resolution
    grid_x_new, grid_y_new = np.mgrid[0:input_h-1:(h*1j), 0:input_w-1:(w*1j)]
    
    # Perform cubic spline interpolation
    interpolated_array = griddata(points, values, (grid_x_new, grid_y_new), method='cubic', fill_value=0)
    
    return interpolated_array[..., np.newaxis]

def transform_to_2d_map(features, electrode_positions, channel_names):
    h, w = 9, 9  # Grid size based on electrode positions
    grid_x, grid_y = np.mgrid[0:h, 0:w]
    positions = np.array([electrode_positions[ch] for ch in channel_names])
    map_2d = griddata(positions, features.reshape(-1, 1), (grid_x, grid_y), method='cubic', fill_value=0)
    return map_2d

def pad_arrays(array_list):
    max_length = max(array.shape[1] for array in array_list)
    padded_array = np.zeros((len(array_list), 62, max_length))
    for i, array in enumerate(array_list):
        padded_array[i, :, :array.shape[1]] = array
    return padded_array

def process_and_save_data(subject_data, subject_labels, subject_id, session_id, trial_indices, data_type='train'):
    spec_input_path = train_specInput_root_path if data_type == 'train' else test_specInput_root_path
    temp_input_path = train_tempInput_root_path if data_type == 'train' else test_tempInput_root_path
    label_path = train_label_root_path if data_type == 'train' else test_label_root_path

    selected_data = [subject_data[i] for i in trial_indices]
    selected_labels = subject_labels[trial_indices]
    
    print(f'Processing subject {subject_id}, session {session_id} with {len(selected_data)} trials')
    spatial_spectral_data = []
    spatial_temporal_data = []
    sfreq = 200  # Sampling frequency
    for trial in selected_data:
        print(f'Processing trial {trial.shape}')
        start_time = time.time()
        # TODO: normalize EEG Data
        info = mne.create_info(channel_names, sfreq=200, ch_types='eeg')
        raw = mne.io.RawArray(trial, info)
        raw.apply_function(lambda x: (x - np.mean(x) / np.std(x)))
        
        de_features = extract_de_features(trial, sfreq, bands)
        print(f'Extracted features {de_features.shape}')
        spectral_maps = np.array([cubic_spline_interpolation(transform_to_2d_map(de_feature, electrode_positions, channel_names)) for de_feature in de_features])
        spectral_maps = np.transpose(spectral_maps, (1, 2, 0, 3))
        print(f'Transformed spectral maps {len(spectral_maps)}')
        
        
        #TODO: do mean or PCA and maybe increase T samples
        # new_sfreq = 200 / (raw.get_data().shape[1] / 25)
        # raw.resample(sfreq=new_sfreq)

        # Downsample the raw data to 40 samples
        pca = PCA(n_components=40)
        print(raw.get_data().shape)
        downsampled_data = pca.fit_transform(raw.get_data())
        print(downsampled_data.shape)
        temporal_maps = np.array([cubic_spline_interpolation(transform_to_2d_map(downsampled_data[:, i], electrode_positions, channel_names)) for i in range(downsampled_data.shape[1])])
        print(f'Transformed temporal maps {len(temporal_maps)}')
        temporal_maps = np.transpose(temporal_maps, (1, 2, 0, 3))
        spatial_temporal_data.append(temporal_maps)
        spatial_spectral_data.append(spectral_maps)
        end_time = time.time()
        print(f'Trial processing took {end_time - start_time} seconds')

    spec_data = np.array(spatial_spectral_data)
    temp_data = np.array(spatial_temporal_data)
    label_data = selected_labels

    os.makedirs(os.path.join(spec_input_path, f'subject_{subject_id}'), exist_ok=True)
    os.makedirs(os.path.join(temp_input_path, f'subject_{subject_id}'), exist_ok=True)
    os.makedirs(os.path.join(label_path, f'subject_{subject_id}'), exist_ok=True)

    np.save(os.path.join(spec_input_path, f'subject_{subject_id}/section_{session_id}_data.npy'), spec_data)
    np.save(os.path.join(temp_input_path, f'subject_{subject_id}/section_{session_id}_data.npy'), temp_data)
    np.save(os.path.join(label_path, f'subject_{subject_id}/section_{session_id}_label.npy'), label_data)

# %%
(subject_data, subject_labels, subject_id, session_id, trial_indices, data_type) = subjects_data[0]
trial = subject_data[0]

info = mne.create_info(channel_names, sfreq=200, ch_types='eeg')
raw = mne.io.RawArray(trial, info)

de_features = extract_de_features(trial, 200, bands)
print(f'Extracted features {de_features.shape}')
spectral_maps = np.array([cubic_spline_interpolation(transform_to_2d_map(de_feature, electrode_positions, channel_names)) for de_feature in de_features])
spectral_maps = np.transpose(spectral_maps, (1, 2, 0, 3))
print(spectral_maps.shape)

# spec_data = np.array([spectral_maps, spectral_maps])
# spec_data.shape
# Out:
# Creating RawArray with float64 data, n_channels=62, n_times=47001
#     Range : 0 ... 47000 =      0.000 ...   235.000 secs
# Ready.
# Extracted features (5, 62)
# (32, 32, 5, 1)

# %%
info = mne.create_info(channel_names, sfreq=200, ch_types='eeg')

raw = mne.io.RawArray(subject_data[0], info)
raw.get_data().shape
pca = PCA(n_components=40)
print(raw.get_data().shape)
downsampled_data = pca.fit_transform(raw.get_data())
print(downsampled_data.shape)

# #plot both data and overlay
# import matplotlib.pyplot as plt
# plt.plot(downsampled_data.T)
# plt.show()
# #plot mne like matplotlib
# raw.plot(bgcolor='w', scalings='auto', title='Data from arrays', show=True, block=True)
# Out:
# Creating RawArray with float64 data, n_channels=62, n_times=47001
#     Range : 0 ... 47000 =      0.000 ...   235.000 secs
# Ready.
# (62, 47001)
# (62, 40)

# %%
for eeg_data, label_data, subject_id, session_id, train_indices, test_indices in subjects_data:
    process_and_save_data(eeg_data, label_data, subject_id, session_id, train_indices, data_type='train')
    process_and_save_data(eeg_data, label_data, subject_id, session_id, test_indices, data_type='test')
# Out:
# Processing subject 10, session 0 with 13 trials
# Processing trial (62, 47601)
# Creating RawArray with float64 data, n_channels=62, n_times=47601
#     Range : 0 ... 47600 =      0.000 ...   238.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47601)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.7885165214538574 seconds
# Processing trial (62, 41201)
# Creating RawArray with float64 data, n_channels=62, n_times=41201
#     Range : 0 ... 41200 =      0.000 ...   206.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 41201)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.7025222778320312 seconds
# Processing trial (62, 47601)
# Creating RawArray with float64 data, n_channels=62, n_times=47601
#     Range : 0 ... 47600 =      0.000 ...   238.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47601)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.4352030754089355 seconds
# Processing trial (62, 47401)
# Creating RawArray with float64 data, n_channels=62, n_times=47401
#     Range : 0 ... 47400 =      0.000 ...   237.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47401)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 2.105135202407837 seconds
# Processing trial (62, 37001)
# Creating RawArray with float64 data, n_channels=62, n_times=37001
#     Range : 0 ... 37000 =      0.000 ...   185.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 37001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.5830214023590088 seconds
# Processing trial (62, 46601)
# Creating RawArray with float64 data, n_channels=62, n_times=46601
#     Range : 0 ... 46600 =      0.000 ...   233.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 46601)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 2.2184860706329346 seconds
# Processing trial (62, 41201)
# Creating RawArray with float64 data, n_channels=62, n_times=41201
#     Range : 0 ... 41200 =      0.000 ...   206.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 41201)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.4149081707000732 seconds
# Processing trial (62, 47001)
# Creating RawArray with float64 data, n_channels=62, n_times=47001
#     Range : 0 ... 47000 =      0.000 ...   235.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.5388100147247314 seconds
# Processing trial (62, 53001)
# Creating RawArray with float64 data, n_channels=62, n_times=53001
#     Range : 0 ... 53000 =      0.000 ...   265.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 53001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.7391431331634521 seconds
# Processing trial (62, 39001)
# Creating RawArray with float64 data, n_channels=62, n_times=39001
#     Range : 0 ... 39000 =      0.000 ...   195.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 39001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.535442590713501 seconds
# Processing trial (62, 43201)
# Creating RawArray with float64 data, n_channels=62, n_times=43201
#     Range : 0 ... 43200 =      0.000 ...   216.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 43201)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 2.0605859756469727 seconds
# Processing trial (62, 46601)
# Creating RawArray with float64 data, n_channels=62, n_times=46601
#     Range : 0 ... 46600 =      0.000 ...   233.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 46601)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.5872290134429932 seconds
# Processing trial (62, 47401)
# Creating RawArray with float64 data, n_channels=62, n_times=47401
#     Range : 0 ... 47400 =      0.000 ...   237.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47401)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.5922799110412598 seconds
# Processing subject 10, session 0 with 2 trials
# Processing trial (62, 47001)
# Creating RawArray with float64 data, n_channels=62, n_times=47001
#     Range : 0 ... 47000 =      0.000 ...   235.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.7285308837890625 seconds
# Processing trial (62, 47001)
# Creating RawArray with float64 data, n_channels=62, n_times=47001
#     Range : 0 ... 47000 =      0.000 ...   235.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.6620466709136963 seconds
# Processing subject 10, session 1 with 13 trials
# Processing trial (62, 47601)
# Creating RawArray with float64 data, n_channels=62, n_times=47601
#     Range : 0 ... 47600 =      0.000 ...   238.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47601)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.5207314491271973 seconds
# Processing trial (62, 41201)
# Creating RawArray with float64 data, n_channels=62, n_times=41201
#     Range : 0 ... 41200 =      0.000 ...   206.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 41201)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.5815801620483398 seconds
# Processing trial (62, 47601)
# Creating RawArray with float64 data, n_channels=62, n_times=47601
#     Range : 0 ... 47600 =      0.000 ...   238.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47601)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.487083911895752 seconds
# Processing trial (62, 47401)
# Creating RawArray with float64 data, n_channels=62, n_times=47401
#     Range : 0 ... 47400 =      0.000 ...   237.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47401)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.492091178894043 seconds
# Processing trial (62, 37001)
# Creating RawArray with float64 data, n_channels=62, n_times=37001
#     Range : 0 ... 37000 =      0.000 ...   185.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 37001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.2659156322479248 seconds
# Processing trial (62, 46601)
# Creating RawArray with float64 data, n_channels=62, n_times=46601
#     Range : 0 ... 46600 =      0.000 ...   233.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 46601)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.605513334274292 seconds
# Processing trial (62, 41201)
# Creating RawArray with float64 data, n_channels=62, n_times=41201
#     Range : 0 ... 41200 =      0.000 ...   206.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 41201)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.6703064441680908 seconds
# Processing trial (62, 47001)
# Creating RawArray with float64 data, n_channels=62, n_times=47001
#     Range : 0 ... 47000 =      0.000 ...   235.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.9225521087646484 seconds
# Processing trial (62, 53001)
# Creating RawArray with float64 data, n_channels=62, n_times=53001
#     Range : 0 ... 53000 =      0.000 ...   265.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 53001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.9101741313934326 seconds
# Processing trial (62, 39001)
# Creating RawArray with float64 data, n_channels=62, n_times=39001
#     Range : 0 ... 39000 =      0.000 ...   195.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 39001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.277759075164795 seconds
# Processing trial (62, 43201)
# Creating RawArray with float64 data, n_channels=62, n_times=43201
#     Range : 0 ... 43200 =      0.000 ...   216.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 43201)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 7.218291282653809 seconds
# Processing trial (62, 46601)
# Creating RawArray with float64 data, n_channels=62, n_times=46601
#     Range : 0 ... 46600 =      0.000 ...   233.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 46601)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 6.702376127243042 seconds
# Processing trial (62, 47401)
# Creating RawArray with float64 data, n_channels=62, n_times=47401
#     Range : 0 ... 47400 =      0.000 ...   237.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47401)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 8.32612657546997 seconds
# Processing subject 10, session 1 with 2 trials
# Processing trial (62, 47001)
# Creating RawArray with float64 data, n_channels=62, n_times=47001
#     Range : 0 ... 47000 =      0.000 ...   235.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 7.7354748249053955 seconds
# Processing trial (62, 47001)
# Creating RawArray with float64 data, n_channels=62, n_times=47001
#     Range : 0 ... 47000 =      0.000 ...   235.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 6.995283842086792 seconds
# Processing subject 10, session 2 with 13 trials
# Processing trial (62, 47601)
# Creating RawArray with float64 data, n_channels=62, n_times=47601
#     Range : 0 ... 47600 =      0.000 ...   238.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47601)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 6.25234317779541 seconds
# Processing trial (62, 41201)
# Creating RawArray with float64 data, n_channels=62, n_times=41201
#     Range : 0 ... 41200 =      0.000 ...   206.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 41201)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 6.910454511642456 seconds
# Processing trial (62, 47601)
# Creating RawArray with float64 data, n_channels=62, n_times=47601
#     Range : 0 ... 47600 =      0.000 ...   238.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47601)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 5.994479656219482 seconds
# Processing trial (62, 47401)
# Creating RawArray with float64 data, n_channels=62, n_times=47401
#     Range : 0 ... 47400 =      0.000 ...   237.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47401)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 5.961163759231567 seconds
# Processing trial (62, 37001)
# Creating RawArray with float64 data, n_channels=62, n_times=37001
#     Range : 0 ... 37000 =      0.000 ...   185.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 37001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 6.109352350234985 seconds
# Processing trial (62, 46601)
# Creating RawArray with float64 data, n_channels=62, n_times=46601
#     Range : 0 ... 46600 =      0.000 ...   233.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 46601)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 6.524072647094727 seconds
# Processing trial (62, 41201)
# Creating RawArray with float64 data, n_channels=62, n_times=41201
#     Range : 0 ... 41200 =      0.000 ...   206.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 41201)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 6.207908868789673 seconds
# Processing trial (62, 47001)
# Creating RawArray with float64 data, n_channels=62, n_times=47001
#     Range : 0 ... 47000 =      0.000 ...   235.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 6.308247089385986 seconds
# Processing trial (62, 53001)
# Creating RawArray with float64 data, n_channels=62, n_times=53001
#     Range : 0 ... 53000 =      0.000 ...   265.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 53001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 7.726716041564941 seconds
# Processing trial (62, 39001)
# Creating RawArray with float64 data, n_channels=62, n_times=39001
#     Range : 0 ... 39000 =      0.000 ...   195.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 39001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 5.309396982192993 seconds
# Processing trial (62, 43201)
# Creating RawArray with float64 data, n_channels=62, n_times=43201
#     Range : 0 ... 43200 =      0.000 ...   216.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 43201)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 5.017305612564087 seconds
# Processing trial (62, 46601)
# Creating RawArray with float64 data, n_channels=62, n_times=46601
#     Range : 0 ... 46600 =      0.000 ...   233.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 46601)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 6.032454490661621 seconds
# Processing trial (62, 47401)
# Creating RawArray with float64 data, n_channels=62, n_times=47401
#     Range : 0 ... 47400 =      0.000 ...   237.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47401)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 8.05617618560791 seconds
# Processing subject 10, session 2 with 2 trials
# Processing trial (62, 47001)
# Creating RawArray with float64 data, n_channels=62, n_times=47001
#     Range : 0 ... 47000 =      0.000 ...   235.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 6.142149925231934 seconds
# Processing trial (62, 47001)
# Creating RawArray with float64 data, n_channels=62, n_times=47001
#     Range : 0 ... 47000 =      0.000 ...   235.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 7.339966535568237 seconds
# Processing subject 11, session 0 with 13 trials
# Processing trial (62, 47601)
# Creating RawArray with float64 data, n_channels=62, n_times=47601
#     Range : 0 ... 47600 =      0.000 ...   238.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47601)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 5.70889687538147 seconds
# Processing trial (62, 41201)
# Creating RawArray with float64 data, n_channels=62, n_times=41201
#     Range : 0 ... 41200 =      0.000 ...   206.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 41201)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 11.381862878799438 seconds
# Processing trial (62, 47601)
# Creating RawArray with float64 data, n_channels=62, n_times=47601
#     Range : 0 ... 47600 =      0.000 ...   238.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47601)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 6.571590185165405 seconds
# Processing trial (62, 47401)
# Creating RawArray with float64 data, n_channels=62, n_times=47401
#     Range : 0 ... 47400 =      0.000 ...   237.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47401)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 7.180410385131836 seconds
# Processing trial (62, 37001)
# Creating RawArray with float64 data, n_channels=62, n_times=37001
#     Range : 0 ... 37000 =      0.000 ...   185.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 37001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 6.76410174369812 seconds
# Processing trial (62, 46601)
# Creating RawArray with float64 data, n_channels=62, n_times=46601
#     Range : 0 ... 46600 =      0.000 ...   233.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 46601)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 8.39295220375061 seconds
# Processing trial (62, 41201)
# Creating RawArray with float64 data, n_channels=62, n_times=41201
#     Range : 0 ... 41200 =      0.000 ...   206.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 41201)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 6.1293559074401855 seconds
# Processing trial (62, 47001)
# Creating RawArray with float64 data, n_channels=62, n_times=47001
#     Range : 0 ... 47000 =      0.000 ...   235.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 7.612133741378784 seconds
# Processing trial (62, 53001)
# Creating RawArray with float64 data, n_channels=62, n_times=53001
#     Range : 0 ... 53000 =      0.000 ...   265.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 53001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 6.741383790969849 seconds
# Processing trial (62, 39001)
# Creating RawArray with float64 data, n_channels=62, n_times=39001
#     Range : 0 ... 39000 =      0.000 ...   195.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 39001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 6.5472657680511475 seconds
# Processing trial (62, 43201)
# Creating RawArray with float64 data, n_channels=62, n_times=43201
#     Range : 0 ... 43200 =      0.000 ...   216.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 43201)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 5.504155874252319 seconds
# Processing trial (62, 46601)
# Creating RawArray with float64 data, n_channels=62, n_times=46601
#     Range : 0 ... 46600 =      0.000 ...   233.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 46601)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 5.500333070755005 seconds
# Processing trial (62, 47401)
# Creating RawArray with float64 data, n_channels=62, n_times=47401
#     Range : 0 ... 47400 =      0.000 ...   237.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47401)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 5.726829767227173 seconds
# Processing subject 11, session 0 with 2 trials
# Processing trial (62, 47001)
# Creating RawArray with float64 data, n_channels=62, n_times=47001
#     Range : 0 ... 47000 =      0.000 ...   235.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 5.862500905990601 seconds
# Processing trial (62, 47001)
# Creating RawArray with float64 data, n_channels=62, n_times=47001
#     Range : 0 ... 47000 =      0.000 ...   235.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 7.669422149658203 seconds
# Processing subject 11, session 1 with 13 trials
# Processing trial (62, 47601)
# Creating RawArray with float64 data, n_channels=62, n_times=47601
#     Range : 0 ... 47600 =      0.000 ...   238.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47601)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 7.107219219207764 seconds
# Processing trial (62, 41201)
# Creating RawArray with float64 data, n_channels=62, n_times=41201
#     Range : 0 ... 41200 =      0.000 ...   206.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 41201)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 5.857532262802124 seconds
# Processing trial (62, 47601)
# Creating RawArray with float64 data, n_channels=62, n_times=47601
#     Range : 0 ... 47600 =      0.000 ...   238.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47601)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 6.9383509159088135 seconds
# Processing trial (62, 47401)
# Creating RawArray with float64 data, n_channels=62, n_times=47401
#     Range : 0 ... 47400 =      0.000 ...   237.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47401)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.7821965217590332 seconds
# Processing trial (62, 37001)
# Creating RawArray with float64 data, n_channels=62, n_times=37001
#     Range : 0 ... 37000 =      0.000 ...   185.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 37001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.8351035118103027 seconds
# Processing trial (62, 46601)
# Creating RawArray with float64 data, n_channels=62, n_times=46601
#     Range : 0 ... 46600 =      0.000 ...   233.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 46601)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.8882849216461182 seconds
# Processing trial (62, 41201)
# Creating RawArray with float64 data, n_channels=62, n_times=41201
#     Range : 0 ... 41200 =      0.000 ...   206.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 41201)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.5806810855865479 seconds
# Processing trial (62, 47001)
# Creating RawArray with float64 data, n_channels=62, n_times=47001
#     Range : 0 ... 47000 =      0.000 ...   235.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.4386727809906006 seconds
# Processing trial (62, 53001)
# Creating RawArray with float64 data, n_channels=62, n_times=53001
#     Range : 0 ... 53000 =      0.000 ...   265.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 53001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 2.35265851020813 seconds
# Processing trial (62, 39001)
# Creating RawArray with float64 data, n_channels=62, n_times=39001
#     Range : 0 ... 39000 =      0.000 ...   195.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 39001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 6.381155490875244 seconds
# Processing trial (62, 43201)
# Creating RawArray with float64 data, n_channels=62, n_times=43201
#     Range : 0 ... 43200 =      0.000 ...   216.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 43201)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 4.974296569824219 seconds
# Processing trial (62, 46601)
# Creating RawArray with float64 data, n_channels=62, n_times=46601
#     Range : 0 ... 46600 =      0.000 ...   233.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 46601)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 5.7136194705963135 seconds
# Processing trial (62, 47401)
# Creating RawArray with float64 data, n_channels=62, n_times=47401
#     Range : 0 ... 47400 =      0.000 ...   237.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47401)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 6.408754825592041 seconds
# Processing subject 11, session 1 with 2 trials
# Processing trial (62, 47001)
# Creating RawArray with float64 data, n_channels=62, n_times=47001
#     Range : 0 ... 47000 =      0.000 ...   235.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 6.280712366104126 seconds
# Processing trial (62, 47001)
# Creating RawArray with float64 data, n_channels=62, n_times=47001
#     Range : 0 ... 47000 =      0.000 ...   235.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 7.193029403686523 seconds
# Processing subject 11, session 2 with 13 trials
# Processing trial (62, 47601)
# Creating RawArray with float64 data, n_channels=62, n_times=47601
#     Range : 0 ... 47600 =      0.000 ...   238.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47601)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 5.859764099121094 seconds
# Processing trial (62, 41201)
# Creating RawArray with float64 data, n_channels=62, n_times=41201
#     Range : 0 ... 41200 =      0.000 ...   206.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 41201)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 5.3892600536346436 seconds
# Processing trial (62, 47601)
# Creating RawArray with float64 data, n_channels=62, n_times=47601
#     Range : 0 ... 47600 =      0.000 ...   238.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47601)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 5.987822771072388 seconds
# Processing trial (62, 47401)
# Creating RawArray with float64 data, n_channels=62, n_times=47401
#     Range : 0 ... 47400 =      0.000 ...   237.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47401)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 5.334301710128784 seconds
# Processing trial (62, 37001)
# Creating RawArray with float64 data, n_channels=62, n_times=37001
#     Range : 0 ... 37000 =      0.000 ...   185.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 37001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 5.587604999542236 seconds
# Processing trial (62, 46601)
# Creating RawArray with float64 data, n_channels=62, n_times=46601
#     Range : 0 ... 46600 =      0.000 ...   233.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 46601)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 5.859415292739868 seconds
# Processing trial (62, 41201)
# Creating RawArray with float64 data, n_channels=62, n_times=41201
#     Range : 0 ... 41200 =      0.000 ...   206.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 41201)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 5.281901597976685 seconds
# Processing trial (62, 47001)
# Creating RawArray with float64 data, n_channels=62, n_times=47001
#     Range : 0 ... 47000 =      0.000 ...   235.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 5.667700529098511 seconds
# Processing trial (62, 53001)
# Creating RawArray with float64 data, n_channels=62, n_times=53001
#     Range : 0 ... 53000 =      0.000 ...   265.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 53001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 6.66434121131897 seconds
# Processing trial (62, 39001)
# Creating RawArray with float64 data, n_channels=62, n_times=39001
#     Range : 0 ... 39000 =      0.000 ...   195.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 39001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 5.91193413734436 seconds
# Processing trial (62, 43201)
# Creating RawArray with float64 data, n_channels=62, n_times=43201
#     Range : 0 ... 43200 =      0.000 ...   216.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 43201)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 6.442044258117676 seconds
# Processing trial (62, 46601)
# Creating RawArray with float64 data, n_channels=62, n_times=46601
#     Range : 0 ... 46600 =      0.000 ...   233.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 46601)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 6.515210151672363 seconds
# Processing trial (62, 47401)
# Creating RawArray with float64 data, n_channels=62, n_times=47401
#     Range : 0 ... 47400 =      0.000 ...   237.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47401)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 6.438387632369995 seconds
# Processing subject 11, session 2 with 2 trials
# Processing trial (62, 47001)
# Creating RawArray with float64 data, n_channels=62, n_times=47001
#     Range : 0 ... 47000 =      0.000 ...   235.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 6.096160650253296 seconds
# Processing trial (62, 47001)
# Creating RawArray with float64 data, n_channels=62, n_times=47001
#     Range : 0 ... 47000 =      0.000 ...   235.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 5.741127967834473 seconds
# Processing subject 12, session 0 with 13 trials
# Processing trial (62, 47601)
# Creating RawArray with float64 data, n_channels=62, n_times=47601
#     Range : 0 ... 47600 =      0.000 ...   238.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47601)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 5.288732290267944 seconds
# Processing trial (62, 41201)
# Creating RawArray with float64 data, n_channels=62, n_times=41201
#     Range : 0 ... 41200 =      0.000 ...   206.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 41201)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 5.860489845275879 seconds
# Processing trial (62, 47601)
# Creating RawArray with float64 data, n_channels=62, n_times=47601
#     Range : 0 ... 47600 =      0.000 ...   238.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47601)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 6.370259523391724 seconds
# Processing trial (62, 47401)
# Creating RawArray with float64 data, n_channels=62, n_times=47401
#     Range : 0 ... 47400 =      0.000 ...   237.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47401)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 7.560607194900513 seconds
# Processing trial (62, 37001)
# Creating RawArray with float64 data, n_channels=62, n_times=37001
#     Range : 0 ... 37000 =      0.000 ...   185.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 37001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 6.443801403045654 seconds
# Processing trial (62, 46601)
# Creating RawArray with float64 data, n_channels=62, n_times=46601
#     Range : 0 ... 46600 =      0.000 ...   233.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 46601)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 7.060794830322266 seconds
# Processing trial (62, 41201)
# Creating RawArray with float64 data, n_channels=62, n_times=41201
#     Range : 0 ... 41200 =      0.000 ...   206.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 41201)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 6.509517192840576 seconds
# Processing trial (62, 47001)
# Creating RawArray with float64 data, n_channels=62, n_times=47001
#     Range : 0 ... 47000 =      0.000 ...   235.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 6.456623315811157 seconds
# Processing trial (62, 53001)
# Creating RawArray with float64 data, n_channels=62, n_times=53001
#     Range : 0 ... 53000 =      0.000 ...   265.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 53001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 6.357057571411133 seconds
# Processing trial (62, 39001)
# Creating RawArray with float64 data, n_channels=62, n_times=39001
#     Range : 0 ... 39000 =      0.000 ...   195.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 39001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 5.3016273975372314 seconds
# Processing trial (62, 43201)
# Creating RawArray with float64 data, n_channels=62, n_times=43201
#     Range : 0 ... 43200 =      0.000 ...   216.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 43201)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 5.9546122550964355 seconds
# Processing trial (62, 46601)
# Creating RawArray with float64 data, n_channels=62, n_times=46601
#     Range : 0 ... 46600 =      0.000 ...   233.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 46601)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 6.2031145095825195 seconds
# Processing trial (62, 47401)
# Creating RawArray with float64 data, n_channels=62, n_times=47401
#     Range : 0 ... 47400 =      0.000 ...   237.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47401)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 6.373684644699097 seconds
# Processing subject 12, session 0 with 2 trials
# Processing trial (62, 47001)
# Creating RawArray with float64 data, n_channels=62, n_times=47001
#     Range : 0 ... 47000 =      0.000 ...   235.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 6.9529008865356445 seconds
# Processing trial (62, 47001)
# Creating RawArray with float64 data, n_channels=62, n_times=47001
#     Range : 0 ... 47000 =      0.000 ...   235.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 6.484149217605591 seconds
# Processing subject 12, session 1 with 13 trials
# Processing trial (62, 47601)
# Creating RawArray with float64 data, n_channels=62, n_times=47601
#     Range : 0 ... 47600 =      0.000 ...   238.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47601)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 5.764077186584473 seconds
# Processing trial (62, 41201)
# Creating RawArray with float64 data, n_channels=62, n_times=41201
#     Range : 0 ... 41200 =      0.000 ...   206.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 41201)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 6.353366851806641 seconds
# Processing trial (62, 47601)
# Creating RawArray with float64 data, n_channels=62, n_times=47601
#     Range : 0 ... 47600 =      0.000 ...   238.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47601)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 6.854109287261963 seconds
# Processing trial (62, 47401)
# Creating RawArray with float64 data, n_channels=62, n_times=47401
#     Range : 0 ... 47400 =      0.000 ...   237.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47401)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 6.957675457000732 seconds
# Processing trial (62, 37001)
# Creating RawArray with float64 data, n_channels=62, n_times=37001
#     Range : 0 ... 37000 =      0.000 ...   185.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 37001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 8.122870922088623 seconds
# Processing trial (62, 46601)
# Creating RawArray with float64 data, n_channels=62, n_times=46601
#     Range : 0 ... 46600 =      0.000 ...   233.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 46601)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 2.0286052227020264 seconds
# Processing trial (62, 41201)
# Creating RawArray with float64 data, n_channels=62, n_times=41201
#     Range : 0 ... 41200 =      0.000 ...   206.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 41201)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 2.8996758460998535 seconds
# Processing trial (62, 47001)
# Creating RawArray with float64 data, n_channels=62, n_times=47001
#     Range : 0 ... 47000 =      0.000 ...   235.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 3.2072341442108154 seconds
# Processing trial (62, 53001)
# Creating RawArray with float64 data, n_channels=62, n_times=53001
#     Range : 0 ... 53000 =      0.000 ...   265.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 53001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 3.4441585540771484 seconds
# Processing trial (62, 39001)
# Creating RawArray with float64 data, n_channels=62, n_times=39001
#     Range : 0 ... 39000 =      0.000 ...   195.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 39001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 2.4186644554138184 seconds
# Processing trial (62, 43201)
# Creating RawArray with float64 data, n_channels=62, n_times=43201
#     Range : 0 ... 43200 =      0.000 ...   216.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 43201)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.814687728881836 seconds
# Processing trial (62, 46601)
# Creating RawArray with float64 data, n_channels=62, n_times=46601
#     Range : 0 ... 46600 =      0.000 ...   233.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 46601)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.6173913478851318 seconds
# Processing trial (62, 47401)
# Creating RawArray with float64 data, n_channels=62, n_times=47401
#     Range : 0 ... 47400 =      0.000 ...   237.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47401)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.6672606468200684 seconds
# Processing subject 12, session 1 with 2 trials
# Processing trial (62, 47001)
# Creating RawArray with float64 data, n_channels=62, n_times=47001
#     Range : 0 ... 47000 =      0.000 ...   235.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.719414472579956 seconds
# Processing trial (62, 47001)
# Creating RawArray with float64 data, n_channels=62, n_times=47001
#     Range : 0 ... 47000 =      0.000 ...   235.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.4798049926757812 seconds
# Processing subject 12, session 2 with 13 trials
# Processing trial (62, 47601)
# Creating RawArray with float64 data, n_channels=62, n_times=47601
#     Range : 0 ... 47600 =      0.000 ...   238.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47601)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.4886178970336914 seconds
# Processing trial (62, 41201)
# Creating RawArray with float64 data, n_channels=62, n_times=41201
#     Range : 0 ... 41200 =      0.000 ...   206.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 41201)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.3991987705230713 seconds
# Processing trial (62, 47601)
# Creating RawArray with float64 data, n_channels=62, n_times=47601
#     Range : 0 ... 47600 =      0.000 ...   238.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47601)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.4318149089813232 seconds
# Processing trial (62, 47401)
# Creating RawArray with float64 data, n_channels=62, n_times=47401
#     Range : 0 ... 47400 =      0.000 ...   237.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47401)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.4603991508483887 seconds
# Processing trial (62, 37001)
# Creating RawArray with float64 data, n_channels=62, n_times=37001
#     Range : 0 ... 37000 =      0.000 ...   185.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 37001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.2701225280761719 seconds
# Processing trial (62, 46601)
# Creating RawArray with float64 data, n_channels=62, n_times=46601
#     Range : 0 ... 46600 =      0.000 ...   233.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 46601)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.706416130065918 seconds
# Processing trial (62, 41201)
# Creating RawArray with float64 data, n_channels=62, n_times=41201
#     Range : 0 ... 41200 =      0.000 ...   206.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 41201)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.6441586017608643 seconds
# Processing trial (62, 47001)
# Creating RawArray with float64 data, n_channels=62, n_times=47001
#     Range : 0 ... 47000 =      0.000 ...   235.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.5314767360687256 seconds
# Processing trial (62, 53001)
# Creating RawArray with float64 data, n_channels=62, n_times=53001
#     Range : 0 ... 53000 =      0.000 ...   265.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 53001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.7764365673065186 seconds
# Processing trial (62, 39001)
# Creating RawArray with float64 data, n_channels=62, n_times=39001
#     Range : 0 ... 39000 =      0.000 ...   195.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 39001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.3101420402526855 seconds
# Processing trial (62, 43201)
# Creating RawArray with float64 data, n_channels=62, n_times=43201
#     Range : 0 ... 43200 =      0.000 ...   216.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 43201)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.7984602451324463 seconds
# Processing trial (62, 46601)
# Creating RawArray with float64 data, n_channels=62, n_times=46601
#     Range : 0 ... 46600 =      0.000 ...   233.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 46601)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 2.032545566558838 seconds
# Processing trial (62, 47401)
# Creating RawArray with float64 data, n_channels=62, n_times=47401
#     Range : 0 ... 47400 =      0.000 ...   237.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47401)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 7.051017761230469 seconds
# Processing subject 12, session 2 with 2 trials
# Processing trial (62, 47001)
# Creating RawArray with float64 data, n_channels=62, n_times=47001
#     Range : 0 ... 47000 =      0.000 ...   235.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 2.092999219894409 seconds
# Processing trial (62, 47001)
# Creating RawArray with float64 data, n_channels=62, n_times=47001
#     Range : 0 ... 47000 =      0.000 ...   235.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.3638765811920166 seconds
# Processing subject 13, session 0 with 13 trials
# Processing trial (62, 47601)
# Creating RawArray with float64 data, n_channels=62, n_times=47601
#     Range : 0 ... 47600 =      0.000 ...   238.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47601)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.290085792541504 seconds
# Processing trial (62, 41201)
# Creating RawArray with float64 data, n_channels=62, n_times=41201
#     Range : 0 ... 41200 =      0.000 ...   206.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 41201)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.3063573837280273 seconds
# Processing trial (62, 47601)
# Creating RawArray with float64 data, n_channels=62, n_times=47601
#     Range : 0 ... 47600 =      0.000 ...   238.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47601)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.5756232738494873 seconds
# Processing trial (62, 47401)
# Creating RawArray with float64 data, n_channels=62, n_times=47401
#     Range : 0 ... 47400 =      0.000 ...   237.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47401)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.814795970916748 seconds
# Processing trial (62, 37001)
# Creating RawArray with float64 data, n_channels=62, n_times=37001
#     Range : 0 ... 37000 =      0.000 ...   185.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 37001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.4319994449615479 seconds
# Processing trial (62, 46601)
# Creating RawArray with float64 data, n_channels=62, n_times=46601
#     Range : 0 ... 46600 =      0.000 ...   233.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 46601)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.5238685607910156 seconds
# Processing trial (62, 41201)
# Creating RawArray with float64 data, n_channels=62, n_times=41201
#     Range : 0 ... 41200 =      0.000 ...   206.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 41201)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.3860774040222168 seconds
# Processing trial (62, 47001)
# Creating RawArray with float64 data, n_channels=62, n_times=47001
#     Range : 0 ... 47000 =      0.000 ...   235.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.4939935207366943 seconds
# Processing trial (62, 53001)
# Creating RawArray with float64 data, n_channels=62, n_times=53001
#     Range : 0 ... 53000 =      0.000 ...   265.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 53001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.6502110958099365 seconds
# Processing trial (62, 39001)
# Creating RawArray with float64 data, n_channels=62, n_times=39001
#     Range : 0 ... 39000 =      0.000 ...   195.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 39001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.303196907043457 seconds
# Processing trial (62, 43201)
# Creating RawArray with float64 data, n_channels=62, n_times=43201
#     Range : 0 ... 43200 =      0.000 ...   216.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 43201)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.298429012298584 seconds
# Processing trial (62, 46601)
# Creating RawArray with float64 data, n_channels=62, n_times=46601
#     Range : 0 ... 46600 =      0.000 ...   233.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 46601)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.47477388381958 seconds
# Processing trial (62, 47401)
# Creating RawArray with float64 data, n_channels=62, n_times=47401
#     Range : 0 ... 47400 =      0.000 ...   237.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47401)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.506967544555664 seconds
# Processing subject 13, session 0 with 2 trials
# Processing trial (62, 47001)
# Creating RawArray with float64 data, n_channels=62, n_times=47001
#     Range : 0 ... 47000 =      0.000 ...   235.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.8099510669708252 seconds
# Processing trial (62, 47001)
# Creating RawArray with float64 data, n_channels=62, n_times=47001
#     Range : 0 ... 47000 =      0.000 ...   235.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 2.145306348800659 seconds
# Processing subject 13, session 1 with 13 trials
# Processing trial (62, 47601)
# Creating RawArray with float64 data, n_channels=62, n_times=47601
# ...
# Trial processing took 1.4301838874816895 seconds
# Processing trial (62, 43201)
# Creating RawArray with float64 data, n_channels=62, n_times=43201
#     Range : 0 ... 43200 =      0.000 ...   216.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 43201)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.6278886795043945 seconds
# Processing trial (62, 46601)
# Creating RawArray with float64 data, n_channels=62, n_times=46601
#     Range : 0 ... 46600 =      0.000 ...   233.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 46601)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.751845121383667 seconds
# Processing trial (62, 47401)
# Creating RawArray with float64 data, n_channels=62, n_times=47401
#     Range : 0 ... 47400 =      0.000 ...   237.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47401)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.7509996891021729 seconds
# Processing subject 8, session 2 with 2 trials
# Processing trial (62, 47001)
# Creating RawArray with float64 data, n_channels=62, n_times=47001
#     Range : 0 ... 47000 =      0.000 ...   235.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.797830581665039 seconds
# Processing trial (62, 47001)
# Creating RawArray with float64 data, n_channels=62, n_times=47001
#     Range : 0 ... 47000 =      0.000 ...   235.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.8533399105072021 seconds
# Processing subject 9, session 0 with 13 trials
# Processing trial (62, 47601)
# Creating RawArray with float64 data, n_channels=62, n_times=47601
#     Range : 0 ... 47600 =      0.000 ...   238.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47601)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.5844552516937256 seconds
# Processing trial (62, 41201)
# Creating RawArray with float64 data, n_channels=62, n_times=41201
#     Range : 0 ... 41200 =      0.000 ...   206.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 41201)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.450183629989624 seconds
# Processing trial (62, 47601)
# Creating RawArray with float64 data, n_channels=62, n_times=47601
#     Range : 0 ... 47600 =      0.000 ...   238.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47601)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.5589370727539062 seconds
# Processing trial (62, 47401)
# Creating RawArray with float64 data, n_channels=62, n_times=47401
#     Range : 0 ... 47400 =      0.000 ...   237.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47401)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.7104814052581787 seconds
# Processing trial (62, 37001)
# Creating RawArray with float64 data, n_channels=62, n_times=37001
#     Range : 0 ... 37000 =      0.000 ...   185.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 37001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.3571596145629883 seconds
# Processing trial (62, 46601)
# Creating RawArray with float64 data, n_channels=62, n_times=46601
#     Range : 0 ... 46600 =      0.000 ...   233.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 46601)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.449538230895996 seconds
# Processing trial (62, 41201)
# Creating RawArray with float64 data, n_channels=62, n_times=41201
#     Range : 0 ... 41200 =      0.000 ...   206.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 41201)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.258256435394287 seconds
# Processing trial (62, 47001)
# Creating RawArray with float64 data, n_channels=62, n_times=47001
#     Range : 0 ... 47000 =      0.000 ...   235.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.4934921264648438 seconds
# Processing trial (62, 53001)
# Creating RawArray with float64 data, n_channels=62, n_times=53001
#     Range : 0 ... 53000 =      0.000 ...   265.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 53001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.661255121231079 seconds
# Processing trial (62, 39001)
# Creating RawArray with float64 data, n_channels=62, n_times=39001
#     Range : 0 ... 39000 =      0.000 ...   195.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 39001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.4962499141693115 seconds
# Processing trial (62, 43201)
# Creating RawArray with float64 data, n_channels=62, n_times=43201
#     Range : 0 ... 43200 =      0.000 ...   216.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 43201)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.6985065937042236 seconds
# Processing trial (62, 46601)
# Creating RawArray with float64 data, n_channels=62, n_times=46601
#     Range : 0 ... 46600 =      0.000 ...   233.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 46601)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 2.1448922157287598 seconds
# Processing trial (62, 47401)
# Creating RawArray with float64 data, n_channels=62, n_times=47401
#     Range : 0 ... 47400 =      0.000 ...   237.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47401)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 2.4784340858459473 seconds
# Processing subject 9, session 0 with 2 trials
# Processing trial (62, 47001)
# Creating RawArray with float64 data, n_channels=62, n_times=47001
#     Range : 0 ... 47000 =      0.000 ...   235.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.8141350746154785 seconds
# Processing trial (62, 47001)
# Creating RawArray with float64 data, n_channels=62, n_times=47001
#     Range : 0 ... 47000 =      0.000 ...   235.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.9688732624053955 seconds
# Processing subject 9, session 1 with 13 trials
# Processing trial (62, 47601)
# Creating RawArray with float64 data, n_channels=62, n_times=47601
#     Range : 0 ... 47600 =      0.000 ...   238.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47601)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.823500633239746 seconds
# Processing trial (62, 41201)
# Creating RawArray with float64 data, n_channels=62, n_times=41201
#     Range : 0 ... 41200 =      0.000 ...   206.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 41201)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 2.4880564212799072 seconds
# Processing trial (62, 47601)
# Creating RawArray with float64 data, n_channels=62, n_times=47601
#     Range : 0 ... 47600 =      0.000 ...   238.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47601)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 2.3760488033294678 seconds
# Processing trial (62, 47401)
# Creating RawArray with float64 data, n_channels=62, n_times=47401
#     Range : 0 ... 47400 =      0.000 ...   237.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47401)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 2.158653736114502 seconds
# Processing trial (62, 37001)
# Creating RawArray with float64 data, n_channels=62, n_times=37001
#     Range : 0 ... 37000 =      0.000 ...   185.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 37001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.4836139678955078 seconds
# Processing trial (62, 46601)
# Creating RawArray with float64 data, n_channels=62, n_times=46601
#     Range : 0 ... 46600 =      0.000 ...   233.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 46601)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.7468061447143555 seconds
# Processing trial (62, 41201)
# Creating RawArray with float64 data, n_channels=62, n_times=41201
#     Range : 0 ... 41200 =      0.000 ...   206.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 41201)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 1.9369745254516602 seconds
# Processing trial (62, 47001)
# Creating RawArray with float64 data, n_channels=62, n_times=47001
#     Range : 0 ... 47000 =      0.000 ...   235.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 6.590663909912109 seconds
# Processing trial (62, 53001)
# Creating RawArray with float64 data, n_channels=62, n_times=53001
#     Range : 0 ... 53000 =      0.000 ...   265.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 53001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 7.171426296234131 seconds
# Processing trial (62, 39001)
# Creating RawArray with float64 data, n_channels=62, n_times=39001
#     Range : 0 ... 39000 =      0.000 ...   195.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 39001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 6.404187440872192 seconds
# Processing trial (62, 43201)
# Creating RawArray with float64 data, n_channels=62, n_times=43201
#     Range : 0 ... 43200 =      0.000 ...   216.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 43201)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 4.976768732070923 seconds
# Processing trial (62, 46601)
# Creating RawArray with float64 data, n_channels=62, n_times=46601
#     Range : 0 ... 46600 =      0.000 ...   233.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 46601)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 8.498639583587646 seconds
# Processing trial (62, 47401)
# Creating RawArray with float64 data, n_channels=62, n_times=47401
#     Range : 0 ... 47400 =      0.000 ...   237.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47401)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 11.41731309890747 seconds
# Processing subject 9, session 1 with 2 trials
# Processing trial (62, 47001)
# Creating RawArray with float64 data, n_channels=62, n_times=47001
#     Range : 0 ... 47000 =      0.000 ...   235.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 13.873240232467651 seconds
# Processing trial (62, 47001)
# Creating RawArray with float64 data, n_channels=62, n_times=47001
#     Range : 0 ... 47000 =      0.000 ...   235.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 7.7994794845581055 seconds
# Processing subject 9, session 2 with 13 trials
# Processing trial (62, 47601)
# Creating RawArray with float64 data, n_channels=62, n_times=47601
#     Range : 0 ... 47600 =      0.000 ...   238.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47601)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 7.557451963424683 seconds
# Processing trial (62, 41201)
# Creating RawArray with float64 data, n_channels=62, n_times=41201
#     Range : 0 ... 41200 =      0.000 ...   206.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 41201)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 6.31408953666687 seconds
# Processing trial (62, 47601)
# Creating RawArray with float64 data, n_channels=62, n_times=47601
#     Range : 0 ... 47600 =      0.000 ...   238.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47601)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 6.259093761444092 seconds
# Processing trial (62, 47401)
# Creating RawArray with float64 data, n_channels=62, n_times=47401
#     Range : 0 ... 47400 =      0.000 ...   237.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47401)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 7.436541795730591 seconds
# Processing trial (62, 37001)
# Creating RawArray with float64 data, n_channels=62, n_times=37001
#     Range : 0 ... 37000 =      0.000 ...   185.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 37001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 5.8024516105651855 seconds
# Processing trial (62, 46601)
# Creating RawArray with float64 data, n_channels=62, n_times=46601
#     Range : 0 ... 46600 =      0.000 ...   233.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 46601)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 6.5591840744018555 seconds
# Processing trial (62, 41201)
# Creating RawArray with float64 data, n_channels=62, n_times=41201
#     Range : 0 ... 41200 =      0.000 ...   206.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 41201)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 5.8552772998809814 seconds
# Processing trial (62, 47001)
# Creating RawArray with float64 data, n_channels=62, n_times=47001
#     Range : 0 ... 47000 =      0.000 ...   235.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 6.949833154678345 seconds
# Processing trial (62, 53001)
# Creating RawArray with float64 data, n_channels=62, n_times=53001
#     Range : 0 ... 53000 =      0.000 ...   265.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 53001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 7.212758302688599 seconds
# Processing trial (62, 39001)
# Creating RawArray with float64 data, n_channels=62, n_times=39001
#     Range : 0 ... 39000 =      0.000 ...   195.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 39001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 6.351810693740845 seconds
# Processing trial (62, 43201)
# Creating RawArray with float64 data, n_channels=62, n_times=43201
#     Range : 0 ... 43200 =      0.000 ...   216.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 43201)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 7.114781618118286 seconds
# Processing trial (62, 46601)
# Creating RawArray with float64 data, n_channels=62, n_times=46601
#     Range : 0 ... 46600 =      0.000 ...   233.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 46601)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 6.477369785308838 seconds
# Processing trial (62, 47401)
# Creating RawArray with float64 data, n_channels=62, n_times=47401
#     Range : 0 ... 47400 =      0.000 ...   237.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47401)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 7.643367767333984 seconds
# Processing subject 9, session 2 with 2 trials
# Processing trial (62, 47001)
# Creating RawArray with float64 data, n_channels=62, n_times=47001
#     Range : 0 ... 47000 =      0.000 ...   235.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 7.364744186401367 seconds
# Processing trial (62, 47001)
# Creating RawArray with float64 data, n_channels=62, n_times=47001
#     Range : 0 ... 47000 =      0.000 ...   235.000 secs
# Ready.
# Extracted features (5, 62)
# Transformed spectral maps 32
# (62, 47001)
# (62, 40)
# Transformed temporal maps 40
# Trial processing took 8.079241514205933 seconds
